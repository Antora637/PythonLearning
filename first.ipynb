# %%
'hello'
print('Hello World', 'Welcome', sep=' & ', end=' | ') #shift+tab
# Out:
# Hello World & Welcome |

# %%
var='Hello world'
print(var)
# Out:
# Hello world

# %%
id(var) #memory location
# Out:
# 2136812188592

# %%
import sys           #byte 
sys.getsizeof(var)
# Out:
# 52

# %%
x,y,z=10,100,1000
x
# Out:
# 10

# %%
y
# Out:
# 100

# %%
z
# Out:
# 1000

# %%
x=1000 # global variable
def func1():
    print('My num is: ', x)
func1()
# Out:
# My num is:  1000

# %%
def func1():
    x=500  #local variable
    print('My num is: ', x)
func1()
# Out:
# My num is:  500

# %%
def func1():
    global x
    x=500  # now global variable
    print('My num is: ', x)
func1()
print('My num is: ', x)
# Out:
# My num is:  500
# My num is:  500
